# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# # EDA
# <hr>

# %% [markdown]
# ## Table infos

# %%
infos = pd.read_csv('../../data/infos.csv', sep = '|')

# %%
infos.head()
# Out:
#    itemID  simulationPrice promotion
# 0       1             3.43       NaN
# 1       2             9.15       NaN
# 2       3            14.04       NaN
# 3       4            14.10       NaN
# 4       5             7.48       NaN

# %%
infos.dtypes
# Out:
# itemID               int64
# simulationPrice    float64
# promotion           object
# dtype: object

# %%
infos.shape
# Out:
# (10463, 3)

# %%
len(infos) - infos.count()
# Out:
# itemID                0
# simulationPrice       0
# promotion          8620
# dtype: int64

# %%
infos['promotion'].unique()
# Out:
# array([nan, '2018-07-13', '2018-07-01,2018-07-02,2018-07-13',
#        '2018-07-05,2018-07-11', '2018-07-05', '2018-07-01', '2018-07-04',
#        '2018-07-08', '2018-07-08,2018-07-13', '2018-07-09', '2018-06-30',
#        '2018-07-11', '2018-07-06', '2018-07-08,2018-07-11',
#        '2018-06-30,2018-07-13', '2018-06-30,2018-07-01,2018-07-11',
#        '2018-07-06,2018-07-13', '2018-07-06,2018-07-10', '2018-07-10',
#        '2018-07-08,2018-07-10', '2018-06-30,2018-07-04',
#        '2018-07-01,2018-07-10', '2018-07-02', '2018-06-30,2018-07-01',
#        '2018-07-04,2018-07-05,2018-07-06', '2018-07-04,2018-07-05',
#        '2018-07-01,2018-07-06', '2018-06-30,2018-07-06',
#        '2018-07-05,2018-07-13', '2018-07-01,2018-07-02', '2018-07-03',
#        '2018-07-03,2018-07-04,2018-07-05',
#        '2018-07-03,2018-07-04,2018-07-06', '2018-07-03,2018-07-04',
#        '2018-07-03,2018-07-05', '2018-07-04,2018-07-09',
#        '2018-07-04,2018-07-06', '2018-07-02,2018-07-04', '2018-07-12',
#        '2018-07-02,2018-07-03,2018-07-04', '2018-07-02,2018-07-03',
#        '2018-07-01,2018-07-08', '2018-07-02,2018-07-04,2018-07-06',
#        '2018-07-02,2018-07-08', '2018-07-01,2018-07-04',
#        '2018-07-02,2018-07-04,2018-07-08', '2018-07-02,2018-07-12',
#        '2018-07-02,2018-07-04,2018-07-05', '2018-07-02,2018-07-09',
#        '2018-07-04,2018-07-06,2018-07-08', '2018-07-02,2018-07-11',
#        '2018-07-07', '2018-07-07,2018-07-10', '2018-07-02,2018-07-07',
#        '2018-07-03,2018-07-07', '2018-07-02,2018-07-05',
#        '2018-07-02,2018-07-04,2018-07-07', '2018-07-02,2018-07-10',
#        '2018-07-02,2018-07-07,2018-07-10', '2018-07-03,2018-07-10',
#        '2018-07-01,2018-07-07', '2018-07-04,2018-07-07',
#        '2018-06-30,2018-07-05', '2018-07-04,2018-07-12',
#        '2018-07-07,2018-07-08', '2018-07-04,2018-07-10',
#        '2018-07-10,2018-07-12', '2018-07-04,2018-07-12,2018-07-13',
#        '2018-07-04,2018-07-05,2018-07-08',
#        '2018-07-05,2018-07-10,2018-07-11', '2018-07-02,2018-07-06',
#        '2018-07-05,2018-07-10', '2018-07-04,2018-07-06,2018-07-10',
#        '2018-07-01,2018-07-02,2018-07-12', '2018-06-30,2018-07-02',
#        '2018-07-08,2018-07-09', '2018-07-09,2018-07-11',
#        '2018-07-01,2018-07-09', '2018-07-09,2018-07-10',
#        '2018-07-05,2018-07-06', '2018-07-11,2018-07-12',
#        '2018-07-07,2018-07-09', '2018-07-05,2018-07-07',
#        '2018-07-02,2018-07-05,2018-07-07', '2018-07-04,2018-07-08',
#        '2018-07-05,2018-07-09'], dtype=object)

# %% [markdown]
# ## Table items

# %%
items = pd.read_csv('../../data/items.csv', sep = '|')

# %%
items.head()
# Out:
#    itemID  brand  manufacturer  customerRating  category1  category2  \
# 0       1      0             1            4.38          1          1
# 1       2      0             2            3.00          1          2
# 2       3      0             3            5.00          1          3
# 3       4      0             2            4.44          1          2
# 4       5      0             2            2.33          1          1
#
#    category3  recommendedRetailPrice
# 0          1                    8.84
# 1          1                   16.92
# 2          1                   15.89
# 3          1                   40.17
# 4          1                   17.04

# %%
items.shape
# Out:
# (10463, 8)

# %%
items.count()
# Out:
# itemID                    10463
# brand                     10463
# manufacturer              10463
# customerRating            10463
# category1                 10463
# category2                 10463
# category3                 10463
# recommendedRetailPrice    10463
# dtype: int64

# %%
items.nunique()
# Out:
# itemID                    10463
# brand                       275
# manufacturer                253
# customerRating               99
# category1                     8
# category2                    52
# category3                     8
# recommendedRetailPrice     5106
# dtype: int64

# %% [markdown]
# ## Table orders

# %%
orders = pd.read_csv('../../data/orders.csv', sep = '|', parse_dates=['time'])

# %%
orders.head()
# Out:
#                  time  transactID  itemID  order  salesPrice
# 0 2018-01-01 00:01:56     2278968     450      1       17.42
# 1 2018-01-01 00:01:56     2278968      83      1        5.19
# 2 2018-01-01 00:07:11     2255797    7851      2       20.47
# 3 2018-01-01 00:09:24     2278968     450      1       17.42
# 4 2018-01-01 00:09:24     2278968      83      1        5.19

# %%
orders.shape
# Out:
# (2181955, 5)

# %%
orders.count()
# Out:
# time          2181955
# transactID    2181955
# itemID        2181955
# order         2181955
# salesPrice    2181955
# dtype: int64

# %%
orders.dtypes
# Out:
# time          datetime64[ns]
# transactID             int64
# itemID                 int64
# order                  int64
# salesPrice           float64
# dtype: object

# %%
orders.time
# Out:
# 0         2018-01-01 00:01:56
# 1         2018-01-01 00:01:56
# 2         2018-01-01 00:07:11
# 3         2018-01-01 00:09:24
# 4         2018-01-01 00:09:24
#                   ...
# 2181950   2018-06-29 23:54:22
# 2181951   2018-06-29 23:55:09
# 2181952   2018-06-29 23:55:09
# 2181953   2018-06-29 23:55:09
# 2181954   2018-06-29 23:57:01
# Name: time, Length: 2181955, dtype: datetime64[ns]

# %%
orders.time.dt.week
# Out:
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
#            ..
# 2181950    26
# 2181951    26
# 2181952    26
# 2181953    26
# 2181954    26
# Name: time, Length: 2181955, dtype: int64

# %%
orders.groupby('itemID')['salesPrice'].nunique().max()
# Out:
# 22

# %% [markdown]
# # Other things
# <hr>

# %% [markdown]
# ## Evalutation function

# %%
# custo 
# np.sum((prediction - np.maximum(prediction - target, 0) * 1.6) * simulatedPrice)

# %% [markdown]
# ## Submission structure

# %%
# submission = items[['itemID']]
# submission['demandPrediction'] = 0 # prediction here
# submission.to_csv('submission.csv', sep = '|', index=False)

# %% [markdown]
# # First Model (aggregating by every two weeks before target)

# %% [markdown]
# ## - Creating the structure

# %%
df = orders.copy()

# %%
df.tail()
# Out:
#                        time  transactID  itemID  order  salesPrice
# 2181950 2018-06-29 23:54:22     2040347    9217      1       23.50
# 2181951 2018-06-29 23:55:09     2260943    2175      1       11.60
# 2181952 2018-06-29 23:55:09     2260943    2061      1        1.03
# 2181953 2018-06-29 23:55:09     2260943    2195      1       18.73
# 2181954 2018-06-29 23:57:01        2525    8462      1       18.93

# %%
df.tail().time.dt.dayofweek
# Out:
# 2181950    4
# 2181951    4
# 2181952    4
# 2181953    4
# 2181954    4
# Name: time, dtype: int64

# %%
# We want the last dayofweek from training to be 6

# %%
(df.tail().time.dt.dayofyear + 2) // 7
# Out:
# 2181950    26
# 2181951    26
# 2181952    26
# 2181953    26
# 2181954    26
# Name: time, dtype: int64

# %%
(df.head().time.dt.dayofyear + 2) // 7
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: time, dtype: int64

# %%
df['week'] = (df.time.dt.dayofyear + 2 + 7) // 14
# + 7 because we want weeks 25 and 26 to be together, week 0 will be discarded

# %%
maxx = df.week.max()
minn = df.week.min()
minn, maxx
# Out:
# (0, 13)

# %%
n_items = items['itemID'].nunique()
print('total number of items:', n_items)
print('expected number of instances:', n_items * (maxx + 1))
# Out:
# total number of items: 10463
# expected number of instances: 146482

# %%
mi = pd.MultiIndex.from_product([range(0, maxx + 1), items['itemID']], names=['week', 'itemID'])
data = pd.DataFrame(index = mi)

# %%
data = data.join(df.groupby(['week', 'itemID'])[['order']].sum(), how = 'left')

# %%
data.fillna(0, inplace = True)

# %%
data.groupby('itemID').count().min()
# Out:
# order    14
# dtype: int64

# %%
df
# Out:
#                        time  transactID  itemID  order  salesPrice  week
# 0       2018-01-01 00:01:56     2278968     450      1       17.42     0
# 1       2018-01-01 00:01:56     2278968      83      1        5.19     0
# 2       2018-01-01 00:07:11     2255797    7851      2       20.47     0
# 3       2018-01-01 00:09:24     2278968     450      1       17.42     0
# 4       2018-01-01 00:09:24     2278968      83      1        5.19     0
# ...                     ...         ...     ...    ...         ...   ...
# 2181950 2018-06-29 23:54:22     2040347    9217      1       23.50    13
# 2181951 2018-06-29 23:55:09     2260943    2175      1       11.60    13
# 2181952 2018-06-29 23:55:09     2260943    2061      1        1.03    13
# 2181953 2018-06-29 23:55:09     2260943    2195      1       18.73    13
# 2181954 2018-06-29 23:57:01        2525    8462      1       18.93    13
#
# [2181955 rows x 6 columns]

# %%
df.groupby('itemID')['salesPrice'].nunique().describe()
# Out:
# count    9840.000000
# mean        2.375407
# std         1.902204
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max        22.000000
# Name: salesPrice, dtype: float64

# %%
df.groupby('itemID')['salesPrice'].median()
# Out:
# itemID
# 1          3.11
# 2          9.15
# 3         14.04
# 4         14.10
# 5          7.84
#           ...
# 10450     55.65
# 10459     14.71
# 10460    325.67
# 10462    304.30
# 10463    282.16
# Name: salesPrice, Length: 9840, dtype: float64

# %% [markdown]
# ## - Creating features

# %%
# rolling window example with shift
random_df = pd.DataFrame({'B': [0, 1, 2, 3, 4]})
random_df.shift(1).rolling(2).sum()
# Out:
#      B
# 0  NaN
# 1  NaN
# 2  1.0
# 3  3.0
# 4  5.0

# %%
data.reset_index(inplace = True)

# %%
data = pd.merge(data, items[['itemID', 'manufacturer', 'category1', 'category2', 'category3']], on = 'itemID')

# %%
# I am going to create three features: the mean of the orders of the last [1, 2, 4] weeks for each item

# %%
# TODO:
# longer windows
# aggregating by other features
# week pairs since last peek
# week pairs from 2nd last to last peek
#

# %%
data.sort_values('week', inplace = True)

# %%
data
# Out:
#         week  itemID  order  manufacturer  category1  category2  category3
# 0          0       1    0.0             1          1          1          1
# 113596     0    8115    0.0           121          4         38          7
# 28784      0    2057    0.0            57          2         10          2
# 113582     0    8114    0.0           121          4         38          7
# 28798      0    2058    0.0            57          2         10          2
# ...      ...     ...    ...           ...        ...        ...        ...
# 94373     13    6741    0.0             3          7         24          6
# 12487     13     892    3.0             6          1          5          1
# 45597     13    3257    0.0            86          2          8          2
# 12515     13     894    0.0             6          1          5          1
# 146481    13   10463    0.0           253          8         44          8
#
# [146482 rows x 7 columns]

# %%
features = [
    ('itemID', 'item'),
    ('manufacturer', 'manuf'),
    ('category1', 'cat1'),
    ('category2', 'cat2'),
    ('category3', 'cat3')
]
for f, n in features:
    if f not in data.columns:
        print('ops', f)

# %%
features = [('itemID', 'item')]

# %%
# f, name = ('manufacturer', 'manuf')
for f, name in features:
    print(f)
    temp = data.groupby([f, 'week'])[['order']].sum()
    shifted = temp.groupby(f)[['order']].shift(1)
    new_feature_block = pd.DataFrame()
    for n in range(3):
        rolled = shifted.groupby(f, as_index = False)['order'].rolling(2 ** n).mean()
        new_feature_block['%s_%d' % (name, 2 ** n)] = rolled.reset_index(0, drop = True) # rolling has a weird index behavior...
    data = pd.merge(data, new_feature_block.reset_index(), on = [f, 'week'])
# Out:
# itemID

# %%
data.count() # the larger the window, more NaN are expected
# Out:
# week            146482
# itemID          146482
# order           146482
# manufacturer    146482
# category1       146482
# category2       146482
# category3       146482
# item_1          136019
# item_2          125556
# item_4          104630
# dtype: int64

# %%
data.fillna(-1, inplace=True)

# %%
# checking if we got what we wanted
data.query('itemID == 1')
# Out:
#         week  itemID  order  manufacturer  category1  category2  category3  \
# 0          0       1    0.0             1          1          1          1
# 20862      1       1    0.0             1          1          1          1
# 31381      2       1  313.0             1          1          1          1
# 31798      3       1    4.0             1          1          1          1
# 42739      4       1   35.0             1          1          1          1
# 53486      5       1    2.0             1          1          1          1
# 72640      6       1    0.0             1          1          1          1
# 83223      7       1    1.0             1          1          1          1
# 87653      8       1  300.0             1          1          1          1
# 97012      9       1    2.0             1          1          1          1
# 110241    10       1   33.0             1          1          1          1
# 116044    11       1    0.0             1          1          1          1
# 132478    12       1    1.0             1          1          1          1
# 136793    13       1    2.0             1          1          1          1
#
#         item_1  item_2  item_4
# 0         -1.0    -1.0   -1.00
# 20862      0.0    -1.0   -1.00
# 31381      0.0     0.0   -1.00
# 31798    313.0   156.5   -1.00
# 42739      4.0   158.5   79.25
# 53486     35.0    19.5   88.00
# 72640      2.0    18.5   88.50
# 83223      0.0     1.0   10.25
# 87653      1.0     0.5    9.50
# 97012    300.0   150.5   75.75
# 110241     2.0   151.0   75.75
# 116044    33.0    17.5   84.00
# 132478     0.0    16.5   83.75
# 136793     1.0     0.5    9.00

# %% [markdown]
# ##  - fit, predict

# %%
# max expected rmse
from sklearn.metrics import mean_squared_error as mse
# pred = data.loc[1:12].groupby('itemID')['order'].mean().sort_index()
# target_week = data.loc[13:, 'order'].reset_index(level = 0, drop = True).sort_index()
# mse(target_week, pred) ** .5

# %%
train = data.query('1 <= week <= 11').reset_index()
test = data.query('week == 12').reset_index()

# %%
y_train = train.pop('order').values
y_test = test.pop('order').values

X_train = train.values
X_test = test.values

# %%
import xgboost as xgb

# %%
dtrain = xgb.DMatrix(X_train, y_train, missing = -1)
dtest = xgb.DMatrix(X_test, y_test, missing = -1)
# specify parameters via map
param = {'max_depth':6, 'eta':0.01, 'objective':'reg:squarederror'}
num_round = 200
bst = xgb.train(param, dtrain,
                num_round, early_stopping_rounds = 5,
                evals = [(dtrain, 'train'), (dtest, 'test')])
# Out:
# [0]	train-rmse:104.29697	test-rmse:120.49635
# Multiple eval metrics have been passed: 'test-rmse' will be used for early stopping.
#
# Will train until test-rmse hasn't improved in 5 rounds.
# [1]	train-rmse:104.17738	test-rmse:120.39642
# [2]	train-rmse:104.06205	test-rmse:120.29979
# [3]	train-rmse:103.94940	test-rmse:120.21165
# [4]	train-rmse:103.83651	test-rmse:120.12774
# [5]	train-rmse:103.72962	test-rmse:120.03764
# [6]	train-rmse:103.62060	test-rmse:119.95250
# [7]	train-rmse:103.51528	test-rmse:119.87102
# [8]	train-rmse:103.41093	test-rmse:119.78099
# [9]	train-rmse:103.30997	test-rmse:119.68909
# [10]	train-rmse:103.20491	test-rmse:119.58569
# [11]	train-rmse:103.10760	test-rmse:119.50549
# [12]	train-rmse:103.00906	test-rmse:119.42036
# [13]	train-rmse:102.91048	test-rmse:119.33966
# [14]	train-rmse:102.81156	test-rmse:119.26020
# [15]	train-rmse:102.71293	test-rmse:119.16958
# [16]	train-rmse:102.62006	test-rmse:119.06833
# [17]	train-rmse:102.52470	test-rmse:118.99465
# [18]	train-rmse:102.43282	test-rmse:118.91648
# [19]	train-rmse:102.33948	test-rmse:118.84676
# [20]	train-rmse:102.24789	test-rmse:118.77287
# [21]	train-rmse:102.16291	test-rmse:118.71075
# [22]	train-rmse:102.07117	test-rmse:118.64561
# [23]	train-rmse:101.98547	test-rmse:118.57975
# [24]	train-rmse:101.89631	test-rmse:118.50269
# [25]	train-rmse:101.81516	test-rmse:118.43807
# [26]	train-rmse:101.72877	test-rmse:118.36629
# [27]	train-rmse:101.64555	test-rmse:118.31863
# [28]	train-rmse:101.56724	test-rmse:118.25595
# [29]	train-rmse:101.48383	test-rmse:118.18533
# [30]	train-rmse:101.40984	test-rmse:118.12758
# [31]	train-rmse:101.32787	test-rmse:118.06177
# [32]	train-rmse:101.25439	test-rmse:117.99792
# [33]	train-rmse:101.17942	test-rmse:117.94158
# [34]	train-rmse:101.10953	test-rmse:117.88779
# [35]	train-rmse:101.03526	test-rmse:117.82069
# [36]	train-rmse:100.96307	test-rmse:117.76431
# [37]	train-rmse:100.89391	test-rmse:117.70315
# [38]	train-rmse:100.82760	test-rmse:117.65652
# [39]	train-rmse:100.75841	test-rmse:117.59515
# [40]	train-rmse:100.68924	test-rmse:117.54737
# [41]	train-rmse:100.61816	test-rmse:117.48865
# [42]	train-rmse:100.55573	test-rmse:117.44538
# [43]	train-rmse:100.48644	test-rmse:117.38718
# [44]	train-rmse:100.42617	test-rmse:117.33598
# [45]	train-rmse:100.36337	test-rmse:117.28391
# [46]	train-rmse:100.30301	test-rmse:117.23140
# [47]	train-rmse:100.24103	test-rmse:117.17392
# [48]	train-rmse:100.17756	test-rmse:117.12978
# [49]	train-rmse:100.11167	test-rmse:117.08438
# [50]	train-rmse:100.05193	test-rmse:117.03146
# [51]	train-rmse:99.98966	test-rmse:116.98634
# [52]	train-rmse:99.92784	test-rmse:116.94038
# [53]	train-rmse:99.87067	test-rmse:116.90573
# [54]	train-rmse:99.81104	test-rmse:116.86336
# [55]	train-rmse:99.75349	test-rmse:116.81925
# [56]	train-rmse:99.69516	test-rmse:116.78754
# [57]	train-rmse:99.64080	test-rmse:116.75084
# [58]	train-rmse:99.58549	test-rmse:116.72125
# [59]	train-rmse:99.53182	test-rmse:116.69025
# [60]	train-rmse:99.46929	test-rmse:116.64516
# [61]	train-rmse:99.42008	test-rmse:116.61002
# [62]	train-rmse:99.36972	test-rmse:116.56575
# [63]	train-rmse:99.31499	test-rmse:116.54967
# [64]	train-rmse:99.26427	test-rmse:116.51375
# [65]	train-rmse:99.21121	test-rmse:116.50562
# [66]	train-rmse:99.16295	test-rmse:116.49093
# [67]	train-rmse:99.11343	test-rmse:116.49048
# [68]	train-rmse:99.05863	test-rmse:116.45704
# [69]	train-rmse:99.01179	test-rmse:116.43399
# [70]	train-rmse:98.96252	test-rmse:116.40815
# [71]	train-rmse:98.91281	test-rmse:116.38790
# [72]	train-rmse:98.86579	test-rmse:116.39269
# [73]	train-rmse:98.82007	test-rmse:116.37176
# [74]	train-rmse:98.76920	test-rmse:116.33421
# [75]	train-rmse:98.71642	test-rmse:116.31364
# [76]	train-rmse:98.66465	test-rmse:116.28443
# [77]	train-rmse:98.61569	test-rmse:116.25967
# [78]	train-rmse:98.56389	test-rmse:116.22617
# [79]	train-rmse:98.51822	test-rmse:116.23814
# [80]	train-rmse:98.47759	test-rmse:116.21836
# [81]	train-rmse:98.43115	test-rmse:116.19244
# [82]	train-rmse:98.38376	test-rmse:116.17831
# [83]	train-rmse:98.33288	test-rmse:116.14445
# [84]	train-rmse:98.28976	test-rmse:116.13581
# [85]	train-rmse:98.25192	test-rmse:116.11655
# [86]	train-rmse:98.21269	test-rmse:116.12579
# [87]	train-rmse:98.17579	test-rmse:116.09587
# [88]	train-rmse:98.13469	test-rmse:116.07087
# [89]	train-rmse:98.09868	test-rmse:116.05953
# [90]	train-rmse:98.05857	test-rmse:116.03536
# [91]	train-rmse:98.02274	test-rmse:116.05508
# [92]	train-rmse:97.98698	test-rmse:116.03458
# [93]	train-rmse:97.95360	test-rmse:116.00565
# [94]	train-rmse:97.91661	test-rmse:115.98279
# [95]	train-rmse:97.88566	test-rmse:115.96272
# [96]	train-rmse:97.84178	test-rmse:115.95615
# [97]	train-rmse:97.81196	test-rmse:115.93769
# [98]	train-rmse:97.77373	test-rmse:115.92422
# [99]	train-rmse:97.73917	test-rmse:115.90485
# [100]	train-rmse:97.70605	test-rmse:115.93172
# [101]	train-rmse:97.67177	test-rmse:115.90683
# [102]	train-rmse:97.63770	test-rmse:115.87820
# [103]	train-rmse:97.60616	test-rmse:115.85712
# [104]	train-rmse:97.57767	test-rmse:115.83748
# [105]	train-rmse:97.54887	test-rmse:115.81813
# [106]	train-rmse:97.51928	test-rmse:115.80169
# [107]	train-rmse:97.48320	test-rmse:115.77325
# [108]	train-rmse:97.45012	test-rmse:115.76349
# [109]	train-rmse:97.41228	test-rmse:115.73817
# [110]	train-rmse:97.38179	test-rmse:115.71381
# [111]	train-rmse:97.35090	test-rmse:115.70153
# [112]	train-rmse:97.31747	test-rmse:115.67648
# [113]	train-rmse:97.28990	test-rmse:115.66531
# [114]	train-rmse:97.25173	test-rmse:115.65765
# [115]	train-rmse:97.21879	test-rmse:115.63177
# [116]	train-rmse:97.18529	test-rmse:115.60906
# [117]	train-rmse:97.15053	test-rmse:115.59495
# [118]	train-rmse:97.11507	test-rmse:115.56510
# [119]	train-rmse:97.08640	test-rmse:115.54570
# [120]	train-rmse:97.05160	test-rmse:115.52892
# [121]	train-rmse:97.01887	test-rmse:115.51206
# [122]	train-rmse:96.98234	test-rmse:115.50801
# [123]	train-rmse:96.95052	test-rmse:115.49159
# [124]	train-rmse:96.91006	test-rmse:115.47604
# [125]	train-rmse:96.88107	test-rmse:115.45464
# [126]	train-rmse:96.85269	test-rmse:115.44465
# [127]	train-rmse:96.81840	test-rmse:115.44317
# [128]	train-rmse:96.77953	test-rmse:115.43400
# [129]	train-rmse:96.74854	test-rmse:115.42982
# [130]	train-rmse:96.71636	test-rmse:115.42534
# [131]	train-rmse:96.68673	test-rmse:115.41843
# [132]	train-rmse:96.66065	test-rmse:115.40378
# [133]	train-rmse:96.62324	test-rmse:115.38705
# [134]	train-rmse:96.59048	test-rmse:115.37823
# [135]	train-rmse:96.55447	test-rmse:115.36588
# [136]	train-rmse:96.52760	test-rmse:115.36231
# [137]	train-rmse:96.49939	test-rmse:115.35207
# [138]	train-rmse:96.46878	test-rmse:115.33775
# [139]	train-rmse:96.43963	test-rmse:115.32314
# [140]	train-rmse:96.40498	test-rmse:115.31065
# [141]	train-rmse:96.37836	test-rmse:115.30276
# [142]	train-rmse:96.35959	test-rmse:115.29192
# [143]	train-rmse:96.33717	test-rmse:115.27532
# [144]	train-rmse:96.31107	test-rmse:115.26465
# [145]	train-rmse:96.28290	test-rmse:115.25879
# [146]	train-rmse:96.25710	test-rmse:115.25632
# [147]	train-rmse:96.23541	test-rmse:115.24707
# [148]	train-rmse:96.21268	test-rmse:115.23225
# [149]	train-rmse:96.18727	test-rmse:115.22105
# [150]	train-rmse:96.16264	test-rmse:115.20893
# [151]	train-rmse:96.13489	test-rmse:115.20139
# [152]	train-rmse:96.10666	test-rmse:115.18292
# [153]	train-rmse:96.08524	test-rmse:115.17491
# [154]	train-rmse:96.06234	test-rmse:115.17459
# [155]	train-rmse:96.03706	test-rmse:115.15790
# [156]	train-rmse:96.01039	test-rmse:115.14433
# [157]	train-rmse:95.98978	test-rmse:115.13607
# [158]	train-rmse:95.96648	test-rmse:115.12820
# [159]	train-rmse:95.94236	test-rmse:115.11161
# [160]	train-rmse:95.92262	test-rmse:115.10533
# [161]	train-rmse:95.90160	test-rmse:115.10516
# [162]	train-rmse:95.88160	test-rmse:115.09435
# [163]	train-rmse:95.86031	test-rmse:115.08406
# [164]	train-rmse:95.84058	test-rmse:115.07928
# [165]	train-rmse:95.82001	test-rmse:115.08077
# [166]	train-rmse:95.79758	test-rmse:115.07343
# [167]	train-rmse:95.77587	test-rmse:115.06675
# [168]	train-rmse:95.75678	test-rmse:115.05396
# [169]	train-rmse:95.74281	test-rmse:115.05029
# [170]	train-rmse:95.71911	test-rmse:115.04427
# [171]	train-rmse:95.69949	test-rmse:115.03811
# [172]	train-rmse:95.67876	test-rmse:115.03522
# [173]	train-rmse:95.65814	test-rmse:115.02930
# [174]	train-rmse:95.63703	test-rmse:114.97682
# [175]	train-rmse:95.61552	test-rmse:114.97176
# [176]	train-rmse:95.59573	test-rmse:114.92657
# [177]	train-rmse:95.57656	test-rmse:114.88502
# [178]	train-rmse:95.55199	test-rmse:114.88447
# [179]	train-rmse:95.53291	test-rmse:114.84339
# [180]	train-rmse:95.51166	test-rmse:114.83782
# [181]	train-rmse:95.49388	test-rmse:114.79863
# [182]	train-rmse:95.47010	test-rmse:114.79616
# [183]	train-rmse:95.45287	test-rmse:114.76000
# [184]	train-rmse:95.42921	test-rmse:114.75665
# [185]	train-rmse:95.40644	test-rmse:114.75451
# [186]	train-rmse:95.39053	test-rmse:114.72692
# [187]	train-rmse:95.37047	test-rmse:114.72735
# [188]	train-rmse:95.35422	test-rmse:114.72992
# [189]	train-rmse:95.33178	test-rmse:114.73037
# [190]	train-rmse:95.30938	test-rmse:114.72891
# [191]	train-rmse:95.29363	test-rmse:114.73105
# Stopping. Best iteration:
# [186]	train-rmse:95.39053	test-rmse:114.72692

# %%
sub = data.query('week == 13').reset_index()

# %%
y_sub = sub.pop('order').values
X_sub = test.values

# %%
dsub = xgb.DMatrix(X_sub, missing = -1)

# %%
submission = items[['itemID']]
submission['demandPrediction'] = bst.predict(dsub).astype(int)
submission.to_csv('../../submissions/sub_inclass_01.csv', sep = '|', index=False)
submission.head()
# Out:
# /home/tobs/miniconda3/envs/dmc/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    itemID  demandPrediction
# 0       1                26
# 1       2                20
# 2       3                31
# 3       4                15
# 4       5                32

# %%
# wtf is happening?

# %%
data.query('itemID == 10')
# Out:
#         itemID  week  order  manufacturer  category1  category2  category3  \
# 608         10     0    0.0             4          1          1          1
# 20119       10     1    0.0             4          1          1          1
# 30663       10     2    0.0             4          1          1          1
# 39127       10     3    1.0             4          1          1          1
# 50295       10     4  358.0             4          1          1          1
# 54446       10     5    0.0             4          1          1          1
# 72713       10     6   64.0             4          1          1          1
# 74211       10     7    0.0             4          1          1          1
# 89368       10     8    5.0             4          1          1          1
# 100513      10     9    0.0             4          1          1          1
# 109870      10    10    0.0             4          1          1          1
# 115595      10    11    3.0             4          1          1          1
# 132971      10    12    0.0             4          1          1          1
# 142659      10    13    2.0             4          1          1          1
#
#         item_1  item_2  item_4  ...  manuf_4   cat1_1   cat1_2    cat1_4  \
# 608       -1.0    -1.0   -1.00  ...    -1.00     -1.0     -1.0     -1.00
# 20119      0.0    -1.0   -1.00  ...    -1.00   5626.0     -1.0     -1.00
# 30663      0.0     0.0   -1.00  ...    -1.00  20233.0  12929.5     -1.00
# 39127      0.0     0.0   -1.00  ...    -1.00  10732.0  15482.5     -1.00
# 50295      1.0     0.5    0.25  ...   203.25   8367.0   9549.5  11239.50
# 54446    358.0   179.5   89.75  ...   930.75  15971.0  12169.0  13825.75
# 72713      0.0   179.0   89.75  ...   928.75  23765.0  19868.0  14708.75
# 74211     64.0    32.0  105.75  ...  1045.75   9763.0  16764.0  14466.50
# 89368      0.0    32.0  105.50  ...  1190.50  18263.0  14013.0  16940.50
# 100513     5.0     2.5   17.25  ...   514.75  21326.0  19794.5  18279.25
# 109870     0.0     2.5   17.25  ...   626.00  23937.0  22631.5  18322.25
# 115595     0.0     0.0    1.25  ...   661.50  19258.0  21597.5  20696.00
# 132971     3.0     1.5    2.00  ...   478.50  20461.0  19859.5  21245.50
# 142659     0.0     1.5    0.75  ...   493.00  24917.0  22689.0  22143.25
#
#          cat2_1   cat2_2   cat2_4   cat3_1   cat3_2    cat3_4
# 608        -1.0     -1.0    -1.00     -1.0     -1.0     -1.00
# 20119    2226.0     -1.0    -1.00   5626.0     -1.0     -1.00
# 30663    7576.0   4901.0    -1.00  20233.0  12929.5     -1.00
# 39127    6135.0   6855.5    -1.00  10732.0  15482.5     -1.00
# 50295    3119.0   4627.0  4764.00   8367.0   9549.5  11239.50
# 54446    7895.0   5507.0  6181.25  15971.0  12169.0  13825.75
# 72713    8810.0   8352.5  6489.75  23765.0  19868.0  14708.75
# 74211    3430.0   6120.0  5813.50   9763.0  16764.0  14466.50
# 89368    5483.0   4456.5  6404.50  18263.0  14013.0  16940.50
# 100513  10806.0   8144.5  7132.25  21326.0  19794.5  18279.25
# 109870   9425.0  10115.5  7286.00  23937.0  22631.5  18322.25
# 115595   6742.0   8083.5  8114.00  19258.0  21597.5  20696.00
# 132971   7410.0   7076.0  8595.75  20461.0  19859.5  21245.50
# 142659   8274.0   7842.0  7962.75  24917.0  22689.0  22143.25
#
# [14 rows x 22 columns]

# %%
data.query('itemID == 100')
# Out:
#         itemID  week  order  manufacturer  category1  category2  category3  \
# 598        100     0    0.0             4          1          1          1
# 20102      100     1    0.0             4          1          1          1
# 30665      100     2    0.0             4          1          1          1
# 39144      100     3    0.0             4          1          1          1
# 50305      100     4    0.0             4          1          1          1
# 54447      100     5    0.0             4          1          1          1
# 72710      100     6   96.0             4          1          1          1
# 74202      100     7    0.0             4          1          1          1
# 89377      100     8    0.0             4          1          1          1
# 100509     100     9   71.0             4          1          1          1
# 109861     100    10    0.0             4          1          1          1
# 115611     100    11    0.0             4          1          1          1
# 132954     100    12    0.0             4          1          1          1
# 142673     100    13    0.0             4          1          1          1
#
#         item_1  item_2  item_4  ...  manuf_4   cat1_1   cat1_2    cat1_4  \
# 598       -1.0    -1.0   -1.00  ...    -1.00     -1.0     -1.0     -1.00
# 20102      0.0    -1.0   -1.00  ...    -1.00   5626.0     -1.0     -1.00
# 30665      0.0     0.0   -1.00  ...    -1.00  20233.0  12929.5     -1.00
# 39144      0.0     0.0   -1.00  ...    -1.00  10732.0  15482.5     -1.00
# 50305      0.0     0.0    0.00  ...   203.25   8367.0   9549.5  11239.50
# 54447      0.0     0.0    0.00  ...   930.75  15971.0  12169.0  13825.75
# 72710      0.0     0.0    0.00  ...   928.75  23765.0  19868.0  14708.75
# 74202     96.0    48.0   24.00  ...  1045.75   9763.0  16764.0  14466.50
# 89377      0.0    48.0   24.00  ...  1190.50  18263.0  14013.0  16940.50
# 100509     0.0     0.0   24.00  ...   514.75  21326.0  19794.5  18279.25
# 109861    71.0    35.5   41.75  ...   626.00  23937.0  22631.5  18322.25
# 115611     0.0    35.5   17.75  ...   661.50  19258.0  21597.5  20696.00
# 132954     0.0     0.0   17.75  ...   478.50  20461.0  19859.5  21245.50
# 142673     0.0     0.0   17.75  ...   493.00  24917.0  22689.0  22143.25
#
#          cat2_1   cat2_2   cat2_4   cat3_1   cat3_2    cat3_4
# 598        -1.0     -1.0    -1.00     -1.0     -1.0     -1.00
# 20102    2226.0     -1.0    -1.00   5626.0     -1.0     -1.00
# 30665    7576.0   4901.0    -1.00  20233.0  12929.5     -1.00
# 39144    6135.0   6855.5    -1.00  10732.0  15482.5     -1.00
# 50305    3119.0   4627.0  4764.00   8367.0   9549.5  11239.50
# 54447    7895.0   5507.0  6181.25  15971.0  12169.0  13825.75
# 72710    8810.0   8352.5  6489.75  23765.0  19868.0  14708.75
# 74202    3430.0   6120.0  5813.50   9763.0  16764.0  14466.50
# 89377    5483.0   4456.5  6404.50  18263.0  14013.0  16940.50
# 100509  10806.0   8144.5  7132.25  21326.0  19794.5  18279.25
# 109861   9425.0  10115.5  7286.00  23937.0  22631.5  18322.25
# 115611   6742.0   8083.5  8114.00  19258.0  21597.5  20696.00
# 132954   7410.0   7076.0  8595.75  20461.0  19859.5  21245.50
# 142673   8274.0   7842.0  7962.75  24917.0  22689.0  22143.25
#
# [14 rows x 22 columns]

# %%
data.query('itemID == 1000')
# Out:
#         itemID  week  order  manufacturer  category1  category2  category3  \
# 940       1000     0    0.0            30          1          3          1
# 20832     1000     1    0.0            30          1          3          1
# 31277     1000     2    0.0            30          1          3          1
# 40434     1000     3    0.0            30          1          3          1
# 51366     1000     4    0.0            30          1          3          1
# 55815     1000     5    2.0            30          1          3          1
# 72241     1000     6   62.0            30          1          3          1
# 73771     1000     7    0.0            30          1          3          1
# 90085     1000     8   23.0            30          1          3          1
# 100920    1000     9    0.0            30          1          3          1
# 111343    1000    10    0.0            30          1          3          1
# 116812    1000    11    0.0            30          1          3          1
# 133471    1000    12    0.0            30          1          3          1
# 144208    1000    13    0.0            30          1          3          1
#
#         item_1  item_2  item_4  ...  manuf_4   cat1_1   cat1_2    cat1_4  \
# 940       -1.0    -1.0   -1.00  ...    -1.00     -1.0     -1.0     -1.00
# 20832      0.0    -1.0   -1.00  ...    -1.00   5626.0     -1.0     -1.00
# 31277      0.0     0.0   -1.00  ...    -1.00  20233.0  12929.5     -1.00
# 40434      0.0     0.0   -1.00  ...    -1.00  10732.0  15482.5     -1.00
# 51366      0.0     0.0    0.00  ...    34.75   8367.0   9549.5  11239.50
# 55815      0.0     0.0    0.00  ...    39.00  15971.0  12169.0  13825.75
# 72241      2.0     1.0    0.50  ...    70.00  23765.0  19868.0  14708.75
# 73771     62.0    32.0   16.00  ...    93.75   9763.0  16764.0  14466.50
# 90085      0.0    31.0   16.00  ...    96.25  18263.0  14013.0  16940.50
# 100920    23.0    11.5   21.75  ...   124.50  21326.0  19794.5  18279.25
# 111343     0.0    11.5   21.25  ...   146.00  23937.0  22631.5  18322.25
# 116812     0.0     0.0    5.75  ...   144.50  19258.0  21597.5  20696.00
# 133471     0.0     0.0    5.75  ...   165.25  20461.0  19859.5  21245.50
# 144208     0.0     0.0    0.00  ...   298.50  24917.0  22689.0  22143.25
#
#         cat2_1  cat2_2   cat2_4   cat3_1   cat3_2    cat3_4
# 940       -1.0    -1.0    -1.00     -1.0     -1.0     -1.00
# 20832    376.0    -1.0    -1.00   5626.0     -1.0     -1.00
# 31277   1079.0   727.5    -1.00  20233.0  12929.5     -1.00
# 40434    574.0   826.5    -1.00  10732.0  15482.5     -1.00
# 51366    768.0   671.0   699.25   8367.0   9549.5  11239.50
# 55815   1528.0  1148.0   987.25  15971.0  12169.0  13825.75
# 72241   3546.0  2537.0  1604.00  23765.0  19868.0  14708.75
# 73771    737.0  2141.5  1644.75   9763.0  16764.0  14466.50
# 90085    415.0   576.0  1556.50  18263.0  14013.0  16940.50
# 100920  1482.0   948.5  1545.00  21326.0  19794.5  18279.25
# 111343  1558.0  1520.0  1048.00  23937.0  22631.5  18322.25
# 116812  1364.0  1461.0  1204.75  19258.0  21597.5  20696.00
# 133471  1718.0  1541.0  1530.50  20461.0  19859.5  21245.50
# 144208  3148.0  2433.0  1947.00  24917.0  22689.0  22143.25
#
# [14 rows x 22 columns]

# %%
zeros = data.groupby('itemID')['order'].apply(lambda x : (x == 0).mean())

# %%
plt.hist(zeros, bins = 60);
